# %% [markdown]
# # Lecture 03 - Variables and Data Types

# %% [markdown]
# ## Variables

# %% [markdown]
# Das ist unser erstes *Beispiel* für **Python Code**:

# %%
first_name = 'John'
age = 31
first_name = 'Lisa'   # Variables can be assigned new values at any time
print(age)
print(first_name)
# Out:
# 31
# Lisa

# %%
name = 'Reinhold' # Variables should have meaningful names (not a,b,c)
price = 17.25
23xyz = 5  # Variables must not start with a number or hash mark (#)
# Out:
#   Input In [10]
#     23xyz = 5  # Variables must not start with a number or hash mark (#)
#      ^
# SyntaxError: invalid decimal literal

# %%
a = 3
b = 5
c = A+B # Variables are case sensitive!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\reinhold.cloud.se\Software Development with Python\WS 2022\notebooks4lecture\Lecture_02.ipynb Zelle 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/reinhold.cloud.se/Software%20Development%20with%20Python/WS%202022/notebooks4lecture/Lecture_02.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> a = 3
#       <a href='vscode-notebook-cell:/c%3A/reinhold.cloud.se/Software%20Development%20with%20Python/WS%202022/notebooks4lecture/Lecture_02.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> b = 5
# ----> <a href='vscode-notebook-cell:/c%3A/reinhold.cloud.se/Software%20Development%20with%20Python/WS%202022/notebooks4lecture/Lecture_02.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> c = A+B
#
# NameError: name 'A' is not defined

# %%
type(False) # Boolean Type
# Out:
# bool

# %%
type('Hallo') # String Type
# Out:
# str

# %%
type(4.5) # Float Type
# Out:
# float

# %%
type(3) # Int Type
# Out:
# int

# %%
int_val = int('hallo') # Types can be converted, but value needs to be a valid number!
print(int_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\reinhold.cloud.se\Software Development with Python\WS 2022\notebooks4lecture\Lecture_02.ipynb Zelle 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/reinhold.cloud.se/Software%20Development%20with%20Python/WS%202022/notebooks4lecture/Lecture_02.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> int_val = int('hallo') # Types can be converted, but value needs to be a valid number!
#       <a href='vscode-notebook-cell:/c%3A/reinhold.cloud.se/Software%20Development%20with%20Python/WS%202022/notebooks4lecture/Lecture_02.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> print(int_val)
#
# ValueError: invalid literal for int() with base 10: 'hallo'

# %%
5**2 # power

# %%
5%2 # modulo
# Out:
# 1

# %% [markdown]
# ## Strings

# %% [markdown]
# ### String Functions

# %%
name = 'reinhold ploesch' ## String are declared using '' or ""
another_name = "Iris Groher"

print(name)

print('reinhold\nploesch') # \n represents a 'special character' for new line
# Out:
# reinhold ploesch
# reinhold
# ploesch

# %%
text = '      Hello World     '

# %%
print(text.strip()) # The function strip removes whitespaces from a string
print(text.rstrip())
print(text.lstrip())
# Out:
# Hello World
#       Hello World
# Hello World

# %%
print('hallo'.upper())  # The function upper converts all characters to upper case

print('Reinhold Ploesch'.lower()) # The function upper converts all characters to upper case
print(name.title()) # The function title converts the first character of each word of the string to upper case
print(name)
name = name.title()
# Out:
# HALLO
# reinhold ploesch
# Reinhold Ploesch
# reinhold ploesch

# %% [markdown]
# #### Check Strings

# %%
print(name.isnumeric()) ## checks if the String only contains numbers
print('444'.isnumeric())
# Out:
# False
# True

# %% [markdown]
# #### Len and Find

# %%
name = 'Franz'

# %%
print(len(name)) # len() returns the length of a String = the number of characters (including whitespaces)
print(len('Hello World      '))

print(name.find('a')) # Find searches for a character, or string and returns the index of its first occurence
print(name.find('anz'))
print(name.find('x')) # If the string does not contain the character you are searching for, Python returns -1
# Out:
# 5
# 17
# 2
# 2
# -1

# %% [markdown]
# ### String concatenation

# %%
first_name = 'iris'
last_name = 'groher'

# %%
print('-'*25) # The * operator used with a string prints the String x times.
print(first_name + ' ' + last_name) # Strings can be concatenated (joined togehter) using the + operator
print(first_name, last_name)
print('-------------------------')
# Out:
# -------------------------
# iris groher
# iris groher
# -------------------------

# %% [markdown]
# ### String Formatting

# %%
name = f' Hello {first_name} {last_name}' # The f-String allows formatting strings more easily without the + operator
print(name)
# Out:
#  Hello iris groher

# %% [markdown]
# ## Input/Output

# %%
name = input() # The function input is used to read input from the console
print('Text: ', name)

# %%
print(type(name)) # Input always returns a string - no matter what the input is!

# %%
price = input()

# %%
print(type(price))

# %%
val1 = int(input("First Number: "))
val2 = int(input("Last Number: "))

sum_val = val1 + val2
print('The sum of',val1,'and',val2,'is',sum_val)
# Out:
# First Number: 3
# Last Number: 4
# The sum of 3 and 4 is 7

# %%
sum_val = int(val1) + int(val2) #Cast the string to a number before performing calculations!
print('sum: ',sum_val)

# %%
text= "     hello    world    "
print(text)
print(text.rstrip())
# Out:
#      hello    world
#      hello    world
